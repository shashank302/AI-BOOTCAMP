# %%
df_sorted = df.sort_values(by='No_Of_Phases', ascending=False)

# Create sorted bar chart
plt.figure(figsize=(15, 7))
plt.bar(df_sorted['State_UT'], df_sorted['No_Of_Phases'], color='orange')
plt.xticks(rotation=90)
plt.xlabel('States and Union Territories')
plt.ylabel('Number of Phases')
plt.title('Number of Election Phases per State/UT (Sorted)')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df=pd.read_csv('1_The_Schedule_of_GE_to_Lok_Sabha_ii_0.csv')
df.columns = ['Sr_No', 'No_Of_Phases', 'State_UT']

# Convert 'No_Of_Phases' to numeric (in case of any non-numeric entries)
df['No_Of_Phases'] = pd.to_numeric(df['No_Of_Phases'], errors='coerce')

# Drop rows with missing values in 'No_Of_Phases' or 'State_UT'
df = df.dropna(subset=['No_Of_Phases', 'State_UT'])

# Create bar chart using matplotlib
plt.figure(figsize=(15, 7))
plt.bar(df['State_UT'], df['No_Of_Phases'], color='skyblue')
plt.xticks(rotation=90)
plt.xlabel('States and Union Territories')
plt.ylabel('Number of Phases')
plt.title('Number of Election Phases per State/UT')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
